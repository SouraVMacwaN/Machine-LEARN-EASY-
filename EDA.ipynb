# %% [markdown]
# <a href="https://colab.research.google.com/github/SouraVMacwaN/Machine-LEARN-EASY-/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('test.csv')
df.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             1.0                 1.0
# 1                          0             0.0                 3.0
# 2                         4+             1.0                 5.0
# 3                         4+             1.0                 4.0
# 4                          1             0.0                 4.0
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
df.shape
# Out:
# (178630, 11)

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                float64
# Product_Category_1            float64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
print(np.intersect1d(df.columns, df_train.columns))
# Out:
# ['Age' 'City_Category' 'Gender' 'Marital_Status' 'Occupation'
#  'Product_Category_1' 'Product_Category_2' 'Product_Category_3'
#  'Product_ID' 'Stay_In_Current_City_Years' 'User_ID']

# %%
### Merge 
df = df.append(df_train)

# %%
df.shape
# Out:
# (314159, 12)

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                float64
# Product_Category_1            float64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 314159 entries, 0 to 135528
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     314159 non-null  int64
#  1   Product_ID                  314159 non-null  object
#  2   Gender                      314159 non-null  object
#  3   Age                         314159 non-null  object
#  4   Occupation                  314159 non-null  int64
#  5   City_Category               314159 non-null  object
#  6   Stay_In_Current_City_Years  314158 non-null  object
#  7   Marital_Status              314158 non-null  float64
#  8   Product_Category_1          314158 non-null  float64
#  9   Product_Category_2          216707 non-null  float64
#  10  Product_Category_3          95740 non-null   float64
#  11  Purchase                    135528 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 31.2+ MB

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         1
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             97452
# Product_Category_3            218419
# Purchase                      178631
# dtype: int64

# %%
df.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         1
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             97452
# Product_Category_3            218419
# Purchase                      178631
# dtype: int64

# %% [markdown]
# Since userID is just uniqueID so no use

# %%
df.drop(['User_ID'],axis = 1 , inplace = True)

# %%
df.head()
# Out:
#   Product_ID Gender    Age  Occupation City_Category  \
# 0  P00128942      M  46-50           7             B
# 1  P00113442      M  26-35          17             C
# 2  P00288442      F  36-45           1             B
# 3  P00145342      F  36-45           1             B
# 4  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             1.0                 1.0
# 1                          0             0.0                 3.0
# 2                         4+             1.0                 5.0
# 3                         4+             1.0                 4.0
# 4                          1             0.0                 4.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                11.0                 NaN       NaN
# 1                 5.0                 NaN       NaN
# 2                14.0                 NaN       NaN
# 3                 9.0                 NaN       NaN
# 4                 5.0                12.0       NaN

# %% [markdown]
# Handling Categorical Variables

# %%
## We can handle the Age category by using dummies method, but here we will use mapping to certain values

df['Gender'] = df['Gender'].map({'F' : 0 , 'M' : 1})
df.head()
# Out:
#   Product_ID  Gender    Age  Occupation City_Category  \
# 0  P00128942       1  46-50           7             B
# 1  P00113442       1  26-35          17             C
# 2  P00288442       0  36-45           1             B
# 3  P00145342       0  36-45           1             B
# 4  P00053842       0  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             1.0                 1.0
# 1                          0             0.0                 3.0
# 2                         4+             1.0                 5.0
# 3                         4+             1.0                 4.0
# 4                          1             0.0                 4.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                11.0                 NaN       NaN
# 1                 5.0                 NaN       NaN
# 2                14.0                 NaN       NaN
# 3                 9.0                 NaN       NaN
# 4                 5.0                12.0       NaN

# %%
## Handling Age

df['Age'].unique()
# Out:
# array(['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17'],
#       dtype=object)

# %% [markdown]
# # Limitation of label Encoding
# Label encoding converts the data in machine-readable form, but it assigns a unique number(starting from 0) to each class of data. This may lead to the generation of priority issues in the training of data sets. A label with a high value may be considered to have high priority than a label having a lower value.

# %%
df['Age'] = df['Age'].map({'0-17' : 1 , '18-25' : 2 , '26-35' : 3 , '36-45' : 4,'46-50' : 5 , '51-55' : 6 ,'55+' : 7})
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00128942       1    5           7             B
# 1  P00113442       1    3          17             C
# 2  P00288442       0    4           1             B
# 3  P00145342       0    4           1             B
# 4  P00053842       0    3           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             1.0                 1.0
# 1                          0             0.0                 3.0
# 2                         4+             1.0                 5.0
# 3                         4+             1.0                 4.0
# 4                          1             0.0                 4.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                11.0                 NaN       NaN
# 1                 5.0                 NaN       NaN
# 2                14.0                 NaN       NaN
# 3                 9.0                 NaN       NaN
# 4                 5.0                12.0       NaN

# %%
df_city = pd.get_dummies(df['City_Category'],drop_first=True)

# %%
df = pd.concat([df,df_city],axis = 1)
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00128942       1    5           7             B
# 1  P00113442       1    3          17             C
# 2  P00288442       0    4           1             B
# 3  P00145342       0    4           1             B
# 4  P00053842       0    3           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             1.0                 1.0
# 1                          0             0.0                 3.0
# 2                         4+             1.0                 5.0
# 3                         4+             1.0                 4.0
# 4                          1             0.0                 4.0
#
#    Product_Category_2  Product_Category_3  Purchase  B  C
# 0                11.0                 NaN       NaN  1  0
# 1                 5.0                 NaN       NaN  0  1
# 2                14.0                 NaN       NaN  1  0
# 3                 9.0                 NaN       NaN  1  0
# 4                 5.0                12.0       NaN  0  1

# %%
df = df.drop('City_Category',axis = 1)

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00128942       1    5           7                          2
# 1  P00113442       1    3          17                          0
# 2  P00288442       0    4           1                         4+
# 3  P00145342       0    4           1                         4+
# 4  P00053842       0    3           1                          1
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0             1.0                 1.0                11.0                 NaN
# 1             0.0                 3.0                 5.0                 NaN
# 2             1.0                 5.0                14.0                 NaN
# 3             1.0                 4.0                 9.0                 NaN
# 4             0.0                 4.0                 5.0                12.0
#
#    Purchase  B  C
# 0       NaN  1  0
# 1       NaN  0  1
# 2       NaN  1  0
# 3       NaN  1  0
# 4       NaN  0  1

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         1
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             97452
# Product_Category_3            218419
# Purchase                      178631
# B                                  0
# C                                  0
# dtype: int64

# %%
df['Product_Category_2'].unique()
# Out:
# array([11.,  5., 14.,  9.,  3.,  4., 13.,  2., nan,  8., 15., 17., 12.,
#        16.,  6., 10., 18.,  7.])

# %% [markdown]
# Discrete data may only be recorded or reported as certain values while continuous data may be any value within a certain range.

# %%
import missingno as msno
msno.matrix(df)

# %% [markdown]
# Since, Categorical Features have NaN values we use mode to fill it
#
# We cannot discard the data/column since it is required in prediction

# %%
df.describe()
# Out:
#               Gender            Age     Occupation  Marital_Status  \
# count  314159.000000  314159.000000  314159.000000   314158.000000
# mean        0.753749       3.494358       8.088528        0.409915
# std         0.430827       1.354316       6.524076        0.491818
# min         0.000000       1.000000       0.000000        0.000000
# 25%         1.000000       3.000000       2.000000        0.000000
# 50%         1.000000       3.000000       7.000000        0.000000
# 75%         1.000000       4.000000      14.000000        1.000000
# max         1.000000       7.000000      20.000000        1.000000
#
#        Product_Category_1  Product_Category_2  Product_Category_3  \
# count       314158.000000       216707.000000        95740.000000
# mean             5.288527            9.851592           12.664362
# std              3.740898            5.092866            4.122018
# min              1.000000            2.000000            3.000000
# 25%              1.000000            5.000000            9.000000
# 50%              5.000000            9.000000           14.000000
# 75%              8.000000           15.000000           16.000000
# max             18.000000           18.000000           18.000000
#
#             Purchase              B              C
# count  135528.000000  314159.000000  314159.000000
# mean     9300.093700       0.421630       0.310235
# std      4980.141216       0.493821       0.462590
# min       185.000000       0.000000       0.000000
# 25%      5847.000000       0.000000       0.000000
# 50%      8051.000000       0.000000       0.000000
# 75%     12057.000000       1.000000       1.000000
# max     23961.000000       1.000000       1.000000

# %%
df['Product_Category_2'].mode()[0] ## Mode : Max repeating numbers
# Out:
# 8.0

# %%
df['Product_Category_2'] = df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00128942       1    5           7                          2
# 1  P00113442       1    3          17                          0
# 2  P00288442       0    4           1                         4+
# 3  P00145342       0    4           1                         4+
# 4  P00053842       0    3           1                          1
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0             1.0                 1.0                11.0                 NaN
# 1             0.0                 3.0                 5.0                 NaN
# 2             1.0                 5.0                14.0                 NaN
# 3             1.0                 4.0                 9.0                 NaN
# 4             0.0                 4.0                 5.0                12.0
#
#    Purchase  B  C
# 0       NaN  1  0
# 1       NaN  0  1
# 2       NaN  1  0
# 3       NaN  1  0
# 4       NaN  0  1

# %%
df['Product_Category_3'] = df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         1
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      178631
# B                                  0
# C                                  0
# dtype: int64

# %%
df = df.dropna(subset=['Stay_In_Current_City_Years', 'Marital_Status','Product_Category_1'])

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      178630
# B                                  0
# C                                  0
# dtype: int64

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '0', '4+', '1', '3'], dtype=object)

# %%
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].str.replace('+',' ')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00128942       1    5           7                          2
# 1  P00113442       1    3          17                          0
# 2  P00288442       0    4           1                         4
# 3  P00145342       0    4           1                         4
# 4  P00053842       0    3           1                          1
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0             1.0                 1.0                11.0                16.0
# 1             0.0                 3.0                 5.0                16.0
# 2             1.0                 5.0                14.0                16.0
# 3             1.0                 4.0                 9.0                16.0
# 4             0.0                 4.0                 5.0                12.0
#
#    Purchase  B  C
# 0       NaN  1  0
# 1       NaN  0  1
# 2       NaN  1  0
# 3       NaN  1  0
# 4       NaN  0  1

# %%
df.dtypes
# Out:
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# Stay_In_Current_City_Years     object
# Marital_Status                float64
# Product_Category_1            float64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# B                               uint8
# C                               uint8
# dtype: object

# %%
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].astype(int)

# %%
df.dtypes
# Out:
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# Stay_In_Current_City_Years      int64
# Marital_Status                float64
# Product_Category_1            float64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# B                               uint8
# C                               uint8
# dtype: object

# %%
df.drop(['Product_ID'],axis = 1 , inplace = True)

# %%
df.head()
# Out:
#    Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0       1    5           7                           2             1.0
# 1       1    3          17                           0             0.0
# 2       0    4           1                           4             1.0
# 3       0    4           1                           4             1.0
# 4       0    3           1                           1             0.0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase  B  C
# 0                 1.0                11.0                16.0       NaN  1  0
# 1                 3.0                 5.0                16.0       NaN  0  1
# 2                 5.0                14.0                16.0       NaN  1  0
# 3                 4.0                 9.0                16.0       NaN  1  0
# 4                 4.0                 5.0                12.0       NaN  0  1

# %%
df_test = df[df['Purchase'].isnull()]
df_train = df[df['Purchase'].notnull()]

# %%
X = df_train.drop(['Purchase'],axis = 1)
y = df_train['Purchase']

# %%
y.shape
# Out:
# (135528,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from google.colab import files

df.to_csv('output.csv', encoding = 'utf-8-sig') 
files.download('output.csv')
